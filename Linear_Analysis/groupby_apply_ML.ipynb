# %% [markdown]
# # An example of a use of groupby apply to apply a model to a set of individual groups

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split

# %%
X, y, coef = make_regression(n_samples=100, 
                             n_features=10, 
                             n_informative=5, 
                             n_targets=1, 
                             bias=0.0, 
                             effective_rank=None, 
                             tail_strength=0.5, 
                             noise=100, 
                             shuffle=True, 
                             coef=True, 
                             random_state=42)

# %%
pd.DataFrame(coef, index=[f"feat_{x}" for x in range(0, coef.shape[0])]).T
# Out:
#       feat_0  feat_1  feat_2     feat_3  feat_4     feat_5  feat_6     feat_7  \
# 0  16.748258     0.0     0.0  63.643025     0.0  70.647573     0.0  10.456784
#
#      feat_8  feat_9
# 0  3.158614     0.0

# %%
df = (pd.DataFrame(X, columns=[f"feat_{x}" for x in range(0, X.shape[1])])
.merge(pd.DataFrame(y, columns=["target"]),
      left_index=True,
      right_index=True))

# %%
df.shape
# Out:
# (100, 11)

# %%
df["group"] = np.repeat(range(0, 10), 10)

# %%
df.head()
# Out:
#      feat_0    feat_1    feat_2    feat_3    feat_4    feat_5    feat_6  \
# 0 -0.926930 -1.430141  1.632411 -3.241267 -1.247783 -1.024388  0.130741
# 1  0.202923  0.334457  0.285865  1.547505 -0.387702  1.795878  2.010205
# 2 -0.241236  0.456753  0.342725 -1.251539  1.117296  1.443765  0.447709
# 3  0.289775 -1.008086 -2.038125  0.871125 -0.408075 -0.326024 -0.351513
# 4 -0.007973 -0.190339 -1.037246  0.077368  0.538910 -0.861284 -1.382800
#
#      feat_7    feat_8    feat_9      target  group
# 0 -0.059525 -0.252568 -0.440044 -186.494628      0
# 1 -1.515744 -0.612789  0.658544  191.976107      0
# 2  0.352055 -0.082151  0.569767  315.503594      0
# 3  2.075401  1.201214 -1.870792  100.185659      0
# 4  1.479944  1.523124 -0.875618  -40.813080      0

# %%
def my_super_cool_function(df, feat_list, target):
    df = pd.DataFrame(MinMaxScaler().fit_transform(df), index=df.index, columns = df.columns)
    
    X = df[feat_list]
    y = df[target]
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8)
    
    model = LinearRegression()
    _ = model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    return X_test.assign(y_pred = y_pred, target=y_test)

# %%
features_list = (df
                 .filter(regex="feat")
                 .columns
                 .tolist()
                )

# %%
my_super_cool_function(df[df["group"]==0], feat_list = features_list, target = "target")
# Out:
#      feat_0    feat_1    feat_2    feat_3    feat_4    feat_5    feat_6  \
# 1  0.544988  0.935186  0.633147  1.000000  0.363659  1.000000  1.000000
# 3  0.576900  0.223677  0.000000  0.858757  0.355044  0.302377  0.303945
#
#      feat_7    feat_8    feat_9    y_pred    target  group
# 1  0.127226  0.130375  0.829266  0.659026  0.753928    0.0
# 3  1.000000  0.771786  0.000000  0.391783  0.571078    0.0

# %%
df_results = (df
 .groupby("group")
 .apply(my_super_cool_function, features_list, "target")
)

# %%
# (df
#  .groupby("group")
# .describe())

# %%
def magnify():
    return [dict(selector="th",
                 props=[("font-size", "8pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")]),
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])
]

# %%
np.random.seed(25)
cmap = cmap=sns.diverging_palette(5, 250, as_cmap=True)

(df_results[["y_pred", "target"]]
 .assign(difference = lambda x: x.diff(axis=1)["target"])
 .abs()
 .style.background_gradient(cmap, axis=1)
    .set_caption("Hover to magnify")
    .set_table_styles(magnify()))
# Out:
# <style  type="text/css" >
#     #T_1c60e_ th {
#           font-size: 8pt;
#     }    #T_1c60e_ td {
#           padding: 0em 0em;
#     }    #T_1c60e_ th:hover {
#           font-size: 12pt;
#     }    #T_1c60e_ tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }#T_1c60e_row0_col0{
#             background-color:  #96b2d5;
#             color:  #000000;
#         }#T_1c60e_row0_col1,#T_1c60e_row1_col0,#T_1c60e_row2_col0,#T_1c60e_row2_col2,#T_1c60e_row3_col0,#T_1c60e_row4_col0,#T_1c60e_row4_col2,#T_1c60e_row5_col0,#T_1c60e_row6_col2,#T_1c60e_row7_col1,#T_1c60e_row8_col0,#T_1c60e_row9_col0,#T_1c60e_row10_col0,#T_1c60e_row11_col0,#T_1c60e_row12_col0,#T_1c60e_row13_col0,#T_1c60e_row14_col0,#T_1c60e_row14_col2,#T_1c60e_row15_col2,#T_1c60e_row16_col0,#T_1c60e_row16_col2,#T_1c60e_row17_col2,#T_1c60e_row18_col1,#T_1c60e_row19_col1{
#             background-color:  #4479bb;
#             color:  #000000;
#         }#T_1c60e_row0_col2,#T_1c60e_row1_col2,#T_1c60e_row2_col1,#T_1c60e_row3_col1,#T_1c60e_row4_col1,#T_1c60e_row5_col1,#T_1c60e_row6_col0,#T_1c60e_row7_col2,#T_1c60e_row8_col2,#T_1c60e_row9_col1,#T_1c60e_row10_col2,#T_1c60e_row11_col2,#T_1c60e_row12_col2,#T_1c60e_row13_col1,#T_1c60e_row14_col1,#T_1c60e_row15_col0,#T_1c60e_row16_col1,#T_1c60e_row17_col0,#T_1c60e_row18_col2,#T_1c60e_row19_col2{
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#         }#T_1c60e_row1_col1{
#             background-color:  #487cbc;
#             color:  #000000;
#         }#T_1c60e_row3_col2{
#             background-color:  #6e96c8;
#             color:  #000000;
#         }#T_1c60e_row5_col2{
#             background-color:  #81a3ce;
#             color:  #000000;
#         }#T_1c60e_row6_col1{
#             background-color:  #f0e4e6;
#             color:  #000000;
#         }#T_1c60e_row7_col0{
#             background-color:  #95b1d5;
#             color:  #000000;
#         }#T_1c60e_row8_col1{
#             background-color:  #c7d4e5;
#             color:  #000000;
#         }#T_1c60e_row9_col2{
#             background-color:  #4b7ebd;
#             color:  #000000;
#         }#T_1c60e_row10_col1{
#             background-color:  #f0e0e3;
#             color:  #000000;
#         }#T_1c60e_row11_col1{
#             background-color:  #dbe2eb;
#             color:  #000000;
#         }#T_1c60e_row12_col1{
#             background-color:  #dd627b;
#             color:  #000000;
#         }#T_1c60e_row13_col2{
#             background-color:  #dee4ec;
#             color:  #000000;
#         }#T_1c60e_row15_col1{
#             background-color:  #89a9d1;
#             color:  #000000;
#         }#T_1c60e_row17_col1{
#             background-color:  #c4d2e4;
#             color:  #000000;
#         }#T_1c60e_row18_col0{
#             background-color:  #6791c6;
#             color:  #000000;
#         }#T_1c60e_row19_col0{
#             background-color:  #d8405e;
#             color:  #f1f1f1;
#         }</style><table id="T_1c60e_" ><caption>Hover to magnify</caption><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >y_pred</th>        <th class="col_heading level0 col1" >target</th>        <th class="col_heading level0 col2" >difference</th>    </tr>    <tr>        <th class="index_name level0" >group</th>        <th class="index_name level1" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1c60e_level0_row0" class="row_heading level0 row0" rowspan="2">0</th>
#                         <th id="T_1c60e_level1_row0" class="row_heading level1 row0" >5</th>
#                         <td id="T_1c60e_row0_col0" class="data row0 col0" >0.167801</td>
#                         <td id="T_1c60e_row0_col1" class="data row0 col1" >0.208114</td>
#                         <td id="T_1c60e_row0_col2" class="data row0 col2" >0.040312</td>
#             </tr>
#             <tr>
#                                 <th id="T_1c60e_level1_row1" class="row_heading level1 row1" >1</th>
#                         <td id="T_1c60e_row1_col0" class="data row1 col0" >0.764280</td>
#                         <td id="T_1c60e_row1_col1" class="data row1 col1" >0.753928</td>
#                         <td id="T_1c60e_row1_col2" class="data row1 col2" >0.010352</td>
#             </tr>
#             <tr>
#                         <th id="T_1c60e_level0_row2" class="row_heading level0 row2" rowspan="2">1</th>
#                         <th id="T_1c60e_level1_row2" class="row_heading level1 row2" >19</th>
#                         <td id="T_1c60e_row2_col0" class="data row2 col0" >0.666128</td>
#                         <td id="T_1c60e_row2_col1" class="data row2 col1" >0.000000</td>
#                         <td id="T_1c60e_row2_col2" class="data row2 col2" >0.666128</td>
#             </tr>
#             <tr>
#                                 <th id="T_1c60e_level1_row3" class="row_heading level1 row3" >12</th>
#                         <td id="T_1c60e_row3_col0" class="data row3 col0" >0.700345</td>
#                         <td id="T_1c60e_row3_col1" class="data row3 col1" >0.076113</td>
#                         <td id="T_1c60e_row3_col2" class="data row3 col2" >0.624233</td>
#             </tr>
#             <tr>
#                         <th id="T_1c60e_level0_row4" class="row_heading level0 row4" rowspan="2">2</th>
#                         <th id="T_1c60e_level1_row4" class="row_heading level1 row4" >22</th>
#                         <td id="T_1c60e_row4_col0" class="data row4 col0" >0.696564</td>
#                         <td id="T_1c60e_row4_col1" class="data row4 col1" >0.000000</td>
#                         <td id="T_1c60e_row4_col2" class="data row4 col2" >0.696564</td>
#             </tr>
#             <tr>
#                                 <th id="T_1c60e_level1_row5" class="row_heading level1 row5" >23</th>
#                         <td id="T_1c60e_row5_col0" class="data row5 col0" >1.656731</td>
#                         <td id="T_1c60e_row5_col1" class="data row5 col1" >0.247903</td>
#                         <td id="T_1c60e_row5_col2" class="data row5 col2" >1.408828</td>
#             </tr>
#             <tr>
#                         <th id="T_1c60e_level0_row6" class="row_heading level0 row6" rowspan="2">3</th>
#                         <th id="T_1c60e_level1_row6" class="row_heading level1 row6" >36</th>
#                         <td id="T_1c60e_row6_col0" class="data row6 col0" >0.062992</td>
#                         <td id="T_1c60e_row6_col1" class="data row6 col1" >0.117258</td>
#                         <td id="T_1c60e_row6_col2" class="data row6 col2" >0.180250</td>
#             </tr>
#             <tr>
#                                 <th id="T_1c60e_level1_row7" class="row_heading level1 row7" >37</th>
#                         <td id="T_1c60e_row7_col0" class="data row7 col0" >0.318920</td>
#                         <td id="T_1c60e_row7_col1" class="data row7 col1" >0.393723</td>
#                         <td id="T_1c60e_row7_col2" class="data row7 col2" >0.074803</td>
#             </tr>
#             <tr>
#                         <th id="T_1c60e_level0_row8" class="row_heading level0 row8" rowspan="2">4</th>
#                         <th id="T_1c60e_level1_row8" class="row_heading level1 row8" >43</th>
#                         <td id="T_1c60e_row8_col0" class="data row8 col0" >0.559197</td>
#                         <td id="T_1c60e_row8_col1" class="data row8 col1" >0.406571</td>
#                         <td id="T_1c60e_row8_col2" class="data row8 col2" >0.152626</td>
#             </tr>
#             <tr>
#                                 <th id="T_1c60e_level1_row9" class="row_heading level1 row9" >40</th>
#                         <td id="T_1c60e_row9_col0" class="data row9 col0" >0.883836</td>
#                         <td id="T_1c60e_row9_col1" class="data row9 col1" >0.019515</td>
#                         <td id="T_1c60e_row9_col2" class="data row9 col2" >0.864321</td>
#             </tr>
#             <tr>
#                         <th id="T_1c

# %%
# _ = plt.figure(figsize=(30, 10))
# _ = sns.heatmap(df
#                 .drop("target", axis=1)
#  .groupby("group")
# .describe())
